# %% [markdown]
# ## Linear Regresion
#
# In this notebook I developed a simplem program for testing the LinearRegresion tool from scikit-learn to a Age / NetWorth data...
# Unfortunately Udacity didn't share its code for 'ageNetWorthData'

# %%
import numpy
import matplotlib
matplotlib.use('agg')

import matplotlib.pyplot as plt
from class_vis import prettyPicture, output_image

from ages_net_worths import ageNetWorthData

from sklearn import linear_model

ages_train, ages_test, net_worths_train, net_worths_test = ageNetWorthData()

#reg = studentReg(ages_train, net_worths_train)
reg = linear_model.LinearRegression()
reg.fit(ages_train, net_worths_train)

## Acessing useful information from the regression model:
print "r-squared score:", reg.score(ages_test, net_worths_test)
print "slope:", reg.coef_
print "intercept:", reg.intercept_


plt.clf()
plt.scatter(ages_train, net_worths_train, color="b", label="train data")
plt.scatter(ages_test, net_worths_test, color="r", label="test data")
plt.plot(ages_test, reg.predict(ages_test), color="black")
plt.legend(loc=2)
plt.xlabel("ages")
plt.ylabel("net worths")

#plt.savefig("test.png")
#output_image("test.png", "png", open("test.png", "rb").read())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-3e03311e6462> in <module>()
#       4
#       5 import matplotlib.pyplot as plt
# ----> 6 from class_vis import prettyPicture, output_image
#       7
#       8 from ages_net_worths import ageNetWorthData
#
# ImportError: No module named class_vis

# %% [markdown]
# ![image.png](attachment:image.png)
